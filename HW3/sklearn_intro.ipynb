# %% [markdown]
# $\textbf{Classifying NIST Handwritten Digits}$  ======================================================We will try to classify handwritten digits (0-9) from their raw pixelated images.Each image is 8x8 pixels.  We will not do any feature extraction and instead classify based on the intensity values for each pixel.

# %%
# %pylab inlinefrom sklearn import datasets, metrics# import NIST digits data set (1797 8x8 images)digits = datasets.load_digits()plt.figure(figsize=(16, 6))for i in range(10):    plt.subplot(1,10,i)    plt.imshow(digits['images'][i],cmap='gray',axes=None)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type &apos;help(pylab)&apos;.

# %% [markdown]
# $\textbf{Now we split the data into a training and testing set.}$$\textbf{We will only fit the classifier on the training set and use the testing set to evaluate performance.}$

# %%
# take the first 500 as trainingtrain = 500Xtr = digits['data'][:train]Ytr = digits['target'][:train]print("training size: " + str(len(Ytr)))# testing setXte = digits['data'][train:]Yte = digits['target'][train:]print("testing size: " + str(len(Yte)))
# Out:
# training size: 500testing size: 1297

# %%
# Create a classifier: a support vector machine classifierfrom sklearn import svm# instantiate classifier objectclassifier = svm.SVC(gamma=0.005) # default: one-versus-one# fit the classification model on training setclassifier.fit(Xtr, Ytr)# make predictions for testing setpred_svm = classifier.predict(Xte) print("True Class / Predicted class")print(vstack((Yte[0:20],pred_svm[0:20])))
# Out:
# True Class / Predicted class[[ 8.  2.  2.  5.  7.  9.  5.  4.  8.  8.  4.  9.  0.  8.  9.  8.  0.  1.   2.  3.] [ 8.  2.  8.  5.  7.  9.  5.  4.  8.  8.  4.  9.  0.  8.  9.  8.  0.  8.   8.  9.]]
# C:\Python27\lib\site-packages\scikit_learn-0.10-py2.7-win32.egg\sklearn\svm\classes.py:184: FutureWarning: SVM: scale_C will be True by default in scikit-learn 0.11  cache_size, scale_C)

# %%
# compute zero-one loss / score & confusion matrixfrom sklearn import metricssvm_01 = metrics.zero_one(Yte, pred_svm) # zero-one losssvm_01_score = metrics.zero_one_score(Yte, pred_svm) # zero-one scoresvm_confmat = metrics.confusion_matrix(Yte, pred_svm) # conf matprint("Zero-One Loss: " + str(svm_01))print("Zero-One Score: " + str(svm_01_score))print("Confusion Matrix:")print("[i, j] is the # of objects truly in group i but predicted to be in group j")print(svm_confmat)
# Out:
# Zero-One Loss: 253Zero-One Score: 0.804934464148Confusion Matrix:[i, j] is the # of objects truly in group i but predicted to be in group j[[108   0   0   0   0   1   0   0  18   0] [  0  80   0   0   0   0   0   0  50   0] [  0   0  98   0   0   0   0   0  29   0] [  0   0   0  88   0   2   0   0  34   6] [  0   0   0   0  89   0   0   1  40   2] [  0   0   0   0   0 120   0   0  10   2] [  0   0   0   0   0   0 113   0  17   0] [  0   0   0   0   0   0   0 116  13   0] [  0   1   0   0   0   0   0   0 126   1] [  0   3   0   1   0   2   0   0  20 106]]

# %%
# plot some digits that we get wrongwrong = np.where(pred_svm != Yte)[0]plt.figure(figsize=(15, 4))for i in range(6):    plt.subplot(1,6,i)    plt.imshow(reshape(Xte[wrong[i]],(8,8)),cmap='gray',axes=None, interpolation='nearest')    title("True = " + str(int(Yte[wrong[i]])) +". Pred = " + str(int(pred_svm[wrong[i]])))

# %%
# compute precision and recall# Note: precision & recall are for 2-class; multi-class returns weighted avg. prec/recallsvm_precision = metrics.precision_score(Yte, pred_svm) # TP / (TP + FP)svm_recall = metrics.recall_score(Yte, pred_svm) # TP / (TP + FN)print("Avg. Precision: ",svm_precision)print("Avg. Recall: ", svm_recall)
# Out:
# (&apos;Avg. Precision: &apos;, 0.915753662087614)(&apos;Avg. Recall: &apos;, 0.80493446414803393)

# %%
# compare to one-versus-all SVMfrom sklearn import multiclass# we can make predicitons in 1 line of code!pred_svm_ovr = multiclass.OneVsRestClassifier(svm.SVC(gamma=0.005)).fit(Xtr, Ytr).predict(Xte)print("0-1 Classification Scores")print("One-versus-One SVM: " + str(round(svm_01_score,3)))print("One-versus-Rest SVM: " + str(round(metrics.zero_one_score(Yte,pred_svm_ovr),3)))
# Out:
# 0-1 Classification ScoresOne-versus-One SVM: 0.805One-versus-Rest SVM: 0.92

# %%
# fit probabilistic SVM (via Platt Scaling)svm_prob = svm.SVC(gamma=0.005,probability=True)svm_prob.fit(Xtr, Ytr)pred_svm_prob = svm_prob.predict_proba(Xte)print("P(digit = 2) for first 6 testing set objects:")print(Yte[0:6])print(pred_svm_prob[0:6,2])
# Out:
# P(digit = 2) for first 6 testing set objects:[8 2 2 5 7 9][ 0.05357152  0.99721852  0.15119723  0.00505313  0.00203027  0.00566795]

# %%
#  ROC curve, AUC for SVM classifier using digit = 1Yte_1 = map(lambda x: x == 1. and 1. or 0.,Yte) # does Y = 1pred_svm_prob_1 = pred_svm_prob[:,1]fpr, tpr, thresholds = metrics.roc_curve(Yte_1, pred_svm_prob_1)plt.figure(figsize=(10, 8))plt.plot(fpr,tpr,'b-',linewidth=3)plt.xlim([0.,0.2])plt.ylim([0.8,1.])xlabel("False Positive Rate",size=15)ylabel("True Positive Rate",size=15)title("ROC Curve for NIST digit=1 SVM Classifier",size=22)print("AUC for digit=1: " + str(metrics.auc(fpr,tpr)))
# Out:
# AUC for digit=1: 0.997037110276

# %% [markdown]
# $\textbf{Tuning the Classifier}$  ======================================================For now we have used a SVM classifier with the arbitrary choice of $\gamma = 0.005$ with the radial basis function kernel. The parameter $\gamma$  is the kernel bandwidth.$\textbf{Let's see how we can rigorously find the optimal model using cross-validation and grid search.}$

# %%
from sklearn import grid_search# explore 2 different kernels and 6 choices of gammaparameters = {'kernel':('linear', 'rbf'), 'gamma':[0.1, 0.01, 0.005, 0.001, 0.0005, 0.0001]}svm_tune = grid_search.GridSearchCV(svm.SVC(), parameters, score_func=metrics.zero_one_score,\                                    n_jobs = 2, cv = 5)svm_opt = svm_tune.fit(Xtr, Ytr)print("Best zero-one score: " + str(svm_opt.best_score) + "\n")print("Optimal Model:\n" + str(svm_opt.best_estimator_))
# Out:
# Best zero-one score: 0.986Optimal Model:SVC(C=1.0, cache_size=200, coef0=0.0, degree=3, gamma=0.001, kernel=rbf,  probability=False, scale_C=False, shrinking=True, tol=0.001)

# %%
# Find the best Random Forest classifierfrom sklearn.ensemble import RandomForestClassifier# explore 3 different forest sizes and 3 choices of mtryparameters = {'n_estimators':[20,50,100],  'max_features':[8,10]}rf_tune = grid_search.GridSearchCV(RandomForestClassifier(), parameters,\                                   score_func=metrics.zero_one_score, n_jobs = 2, cv = 5)rf_opt = rf_tune.fit(Xtr, Ytr)print("Best zero-one score: " + str(rf_opt.best_score) + "\n")print("Optimal Model:\n" + str(rf_opt.best_estimator_))
# Out:
# Best zero-one score: 0.978Optimal Model:RandomForestClassifier(bootstrap=True, compute_importances=False,            criterion=gini, max_depth=None, max_features=10,            min_density=0.1, min_split=1, n_estimators=100, n_jobs=1,            random_state=&lt;mtrand.RandomState object at 0x034FD370&gt;)

# %% [markdown]
# $\textbf{Manifold Learning Example}$  ======================================================The Swiss Roll data set

# %%
from mpl_toolkits.mplot3d import Axes3Dfrom sklearn import datasetsimport pylab as pln_points = 1000X, t = datasets.samples_generator.make_swiss_roll(n_samples=n_points)fig = plt.figure(figsize=(12, 16))ax = fig.add_subplot(211, projection='3d')ax.scatter(X[:,0], X[:,1], X[:,2], c=t, cmap=pl.cm.Spectral)ax1 = fig.add_subplot(212)ax1.scatter(X[:,0], X[:,2], c=t, cmap=pl.cm.Spectral)
# Out:
# &lt;matplotlib.collections.PathCollection at 0x86994d0&gt;

# %%
from sklearn import manifoldout_dim = 2n_neighbors = 10Y = manifold.LocallyLinearEmbedding(n_neighbors, out_dim, eigen_solver='auto',\                                    method='standard').fit_transform(X)plt.figure(figsize=(10, 8))plt.scatter(Y[:, 0], Y[:, 1], c=t, cmap=pl.cm.Spectral)plt.title("LLE",size=25)
# Out:
# <span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ValueError</span>                                Traceback (most recent call last)
# <span class="ansigreen">C:\Users\rkwant\Documents\Berkeley\Classes\Astronomy_250\Weekly_Files\Week4\&lt;ipython-input-13-1f99a32042ae&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      4</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      5</span> Y = manifold.LocallyLinearEmbedding(n_neighbors, out_dim, eigen_solver=&apos;auto&apos;,\
# <span class="ansigreen">----&gt; 6</span><span class="ansiyellow">                                     method=&apos;standard&apos;).fit_transform(X)
# ...

# %%
Y = manifold.LocallyLinearEmbedding(n_neighbors, out_dim, eigen_solver='auto',\                                    method='ltsa').fit_transform(X)plt.figure(figsize=(10, 8))plt.scatter(Y[:, 0], Y[:, 1], c=t, cmap=pl.cm.Spectral)plt.title("LTSA",size=25)

# %%
Y = manifold.Isomap(n_neighbors, out_dim).fit_transform(X)plt.figure(figsize=(10, 8))plt.scatter(Y[:, 0], Y[:, 1], c=t, cmap=pl.cm.Spectral)plt.title("IsoMap",size=25)
