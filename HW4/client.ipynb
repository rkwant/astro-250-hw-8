# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].For more information, type &apos;help(pylab)&apos;.

# %%
import xmlrpclib, sysfrom skimage import data, io, filter, color, img_as_float, morphology, feature, transform, graph, img_as_int, img_as_ubyteio.use_plugin('matplotlib')io.use_plugin('pil', 'imread')import time

# %%
host, port = "", 5022server = xmlrpclib.ServerProxy("http://%s:%d" % (host, port))available_methods = server.system.listMethods()print "Available methods from server:"for method in available_methods:    print "\t" + method
# Out:
# Available methods from server:	channels	hSlice	introspect	system.listMethods	system.methodHelp	system.methodSignature	system.multicall	upsideDown

# %%
test = io.imread('dog.jpg')test = color.rgb2gray(test)back = array(server.upsideDown(test.tolist()))

# %%
plt.imshow(test, cmap='gray')
# Out:
# &lt;matplotlib.image.AxesImage at 0x97c6df0&gt;

# %%
plt.imshow(test[::-1])
# Out:
# &lt;matplotlib.image.AxesImage at 0x5b2bc10&gt;

# %%
test.shape
# Out:
# (193, 314)

# %%
test=array([1,2,3,4])

# %%
test.max()
# Out:
# 4
